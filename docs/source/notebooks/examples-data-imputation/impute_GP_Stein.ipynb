# %%
import numpy as np
import pandas as pd

from mimic.data_imputation.impute_GP import GPImputer
# Out:
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\MIMIC\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\MIMIC\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\MIMIC\Lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.

# %%
data = pd.read_csv('Stein_example_F.csv')

# %%
# Dictionary to hold DataFrames for each unique ID
sample_dfs = {}

for sample_id in data['ID'].unique():
    # Filter data for each sample ID
    sample_data = data[data['ID'] == sample_id].copy()

    # Shift time points to start from 0
    sample_data['time'] = sample_data['time'] - sample_data['time'].min()

    # Store DataFrame in dictionary
    sample_dfs[sample_id] = sample_data

# Display a sample DataFrame for verification
sample_dfs[1].head(20)  # Display the DataFrame for sample ID 1
# Out:
#     ID  time  undefined_genus_of_Enterobacteriaceae   Blautia  Barnesiella  \
# 0    1     0                                5.25900 -1.536500    -3.157200
# 1    1     2                               -0.73919  5.195600    -0.264510
# 2    1     3                                2.50860 -0.424610     2.907600
# 3    1     4                               -2.47510  6.226000    -1.014700
# 4    1     5                               -0.58042  0.082481    -0.217980
# 5    1     6                               -0.52380 -3.085500    -1.861500
# 6    1     7                                0.59652 -0.038938     0.058401
# 7    1     9                                0.07182  0.134260     0.149210
# 8    1    12                               -1.29670 -0.889530    -0.822160
# 9    1    16                                0.21910  0.179860     0.120090
# 10   1    23                               -0.34909 -0.130320    -0.160040
#
#     undefined_genus_of_unclassified_Mollicutes  \
# 0                                     -0.72794
# 1                                      0.42863
# 2                                      2.17330
# 3                                     -1.01470
# 4                                     -0.21801
# 5                                      2.85240
# 6                                      0.81097
# 7                                      0.21998
# 8                                     -0.61591
# 9                                      0.11893
# 10                                    -0.13692
#
#     undefined_genus_of_Lachnospiraceae  Akkermansia  Clostridium_difficile  \
# 0                            -3.778700    -2.561400                    0.0
# 1                            -0.264520     5.569500                    0.0
# 2                             2.907600    -1.697600                    0.0
# 3                            -1.014700     3.979200                    0.0
# 4                            -0.218000    -0.484480                    0.0
# 5                            -1.861500    -0.092136                    0.0
# 6                             0.058389    -3.804400                    0.0
# 7                             0.149210     0.149210                    0.0
# 8                            -0.822140    -0.822150                    0.0
# 9                             0.120090     0.120090                    0.0
# 10                           -0.160050    -0.160040                    0.0
#
#     unclassified_Lachnospiraceae  Coprobacillus  Enterococcus    Other
# 0                      -3.033100       0.280350       2.07960 -1.65810
# 1                      -0.264720       1.967400      -0.82412 -0.44685
# 2                       2.907600       6.399700       4.98700  5.10480
# 3                      -1.014700      -6.452700      -2.17780 -1.54420
# 4                      -0.217620      -0.504010      -2.52060 -1.99110
# 5                      -1.862000      -1.861500       1.02880 -1.57390
# 6                       0.058219       0.058405      -1.04020  0.69655
# 7                       0.149330       0.149210      -0.53718 -0.18033
# 8                      -0.822110      -0.822150      -0.48064 -0.40463
# 9                       0.120130       0.120090       0.12009  0.13895
# 10                     -0.160100      -0.160040      -0.00309 -0.18936

# %%
# Process each sample DataFrame to include all time points from 0 to max with NaN for missing rows
for sample_id in sample_dfs:
    # Get the maximum time point for the current sample
    max_time = sample_dfs[sample_id]['time'].max()

    # Create a new index that includes all time points from 0 to max_time
    full_time_index = pd.RangeIndex(start=0, stop=max_time + 1, step=1)

    # Reindex the DataFrame using the new full time index
    sample_dfs[sample_id] = sample_dfs[sample_id].set_index(
        'time').reindex(full_time_index).reset_index()
    # Fill in the sample ID for new rows which will be NaN after reindexing
    sample_dfs[sample_id]['ID'].fillna(sample_id, inplace=True)

# Display the adjusted DataFrame for sample ID 1 to verify the changes
# Display the first 15 rows to see the complete range including NaNs
sample_dfs[1].head(15)
# Out:
#     index   ID  undefined_genus_of_Enterobacteriaceae   Blautia  Barnesiella  \
# 0       0  1.0                                5.25900 -1.536500    -3.157200
# 1       1  1.0                                    NaN       NaN          NaN
# 2       2  1.0                               -0.73919  5.195600    -0.264510
# 3       3  1.0                                2.50860 -0.424610     2.907600
# 4       4  1.0                               -2.47510  6.226000    -1.014700
# 5       5  1.0                               -0.58042  0.082481    -0.217980
# 6       6  1.0                               -0.52380 -3.085500    -1.861500
# 7       7  1.0                                0.59652 -0.038938     0.058401
# 8       8  1.0                                    NaN       NaN          NaN
# 9       9  1.0                                0.07182  0.134260     0.149210
# 10     10  1.0                                    NaN       NaN          NaN
# 11     11  1.0                                    NaN       NaN          NaN
# 12     12  1.0                               -1.29670 -0.889530    -0.822160
# 13     13  1.0                                    NaN       NaN          NaN
# 14     14  1.0                                    NaN       NaN          NaN
#
#     undefined_genus_of_unclassified_Mollicutes  \
# 0                                     -0.72794
# 1                                          NaN
# 2                                      0.42863
# 3                                      2.17330
# 4                                     -1.01470
# 5                                     -0.21801
# 6                                      2.85240
# 7                                      0.81097
# 8                                          NaN
# 9                                      0.21998
# 10                                         NaN
# 11                                         NaN
# 12                                    -0.61591
# 13                                         NaN
# 14                                         NaN
#
#     undefined_genus_of_Lachnospiraceae  Akkermansia  Clostridium_difficile  \
# 0                            -3.778700    -2.561400                    0.0
# 1                                  NaN          NaN                    NaN
# 2                            -0.264520     5.569500                    0.0
# 3                             2.907600    -1.697600                    0.0
# 4                            -1.014700     3.979200                    0.0
# 5                            -0.218000    -0.484480                    0.0
# 6                            -1.861500    -0.092136                    0.0
# 7                             0.058389    -3.804400                    0.0
# 8                                  NaN          NaN                    NaN
# 9                             0.149210     0.149210                    0.0
# 10                                 NaN          NaN                    NaN
# 11                                 NaN          NaN                    NaN
# 12                           -0.822140    -0.822150                    0.0
# 13                                 NaN          NaN                    NaN
# 14                                 NaN          NaN                    NaN
#
#     unclassified_Lachnospiraceae  Coprobacillus  Enterococcus    Other
# 0                      -3.033100       0.280350       2.07960 -1.65810
# 1                            NaN            NaN           NaN      NaN
# 2                      -0.264720       1.967400      -0.82412 -0.44685
# 3                       2.907600       6.399700       4.98700  5.10480
# 4                      -1.014700      -6.452700      -2.17780 -1.54420
# 5                      -0.217620      -0.504010      -2.52060 -1.99110
# 6                      -1.862000      -1.861500       1.02880 -1.57390
# 7                       0.058219       0.058405      -1.04020  0.69655
# 8                            NaN            NaN           NaN      NaN
# 9                       0.149330       0.149210      -0.53718 -0.18033
# 10                           NaN            NaN           NaN      NaN
# 11                           NaN            NaN           NaN      NaN
# 12                     -0.822110      -0.822150      -0.48064 -0.40463
# 13                           NaN            NaN           NaN      NaN
# 14                           NaN            NaN           NaN      NaN

# %%
data = sample_dfs[1]

data
# Out:
#     index   ID  undefined_genus_of_Enterobacteriaceae   Blautia  Barnesiella  \
# 0       0  1.0                                5.25900 -1.536500    -3.157200
# 1       1  1.0                                    NaN       NaN          NaN
# 2       2  1.0                               -0.73919  5.195600    -0.264510
# 3       3  1.0                                2.50860 -0.424610     2.907600
# 4       4  1.0                               -2.47510  6.226000    -1.014700
# 5       5  1.0                               -0.58042  0.082481    -0.217980
# 6       6  1.0                               -0.52380 -3.085500    -1.861500
# 7       7  1.0                                0.59652 -0.038938     0.058401
# 8       8  1.0                                    NaN       NaN          NaN
# 9       9  1.0                                0.07182  0.134260     0.149210
# 10     10  1.0                                    NaN       NaN          NaN
# 11     11  1.0                                    NaN       NaN          NaN
# 12     12  1.0                               -1.29670 -0.889530    -0.822160
# 13     13  1.0                                    NaN       NaN          NaN
# 14     14  1.0                                    NaN       NaN          NaN
# 15     15  1.0                                    NaN       NaN          NaN
# 16     16  1.0                                0.21910  0.179860     0.120090
# 17     17  1.0                                    NaN       NaN          NaN
# 18     18  1.0                                    NaN       NaN          NaN
# 19     19  1.0                                    NaN       NaN          NaN
# 20     20  1.0                                    NaN       NaN          NaN
# 21     21  1.0                                    NaN       NaN          NaN
# 22     22  1.0                                    NaN       NaN          NaN
# 23     23  1.0                               -0.34909 -0.130320    -0.160040
#
#     undefined_genus_of_unclassified_Mollicutes  \
# 0                                     -0.72794
# 1                                          NaN
# 2                                      0.42863
# 3                                      2.17330
# 4                                     -1.01470
# 5                                     -0.21801
# 6                                      2.85240
# 7                                      0.81097
# 8                                          NaN
# 9                                      0.21998
# 10                                         NaN
# 11                                         NaN
# 12                                    -0.61591
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                     0.11893
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                    -0.13692
#
#     undefined_genus_of_Lachnospiraceae  Akkermansia  Clostridium_difficile  \
# 0                            -3.778700    -2.561400                    0.0
# 1                                  NaN          NaN                    NaN
# 2                            -0.264520     5.569500                    0.0
# 3                             2.907600    -1.697600                    0.0
# 4                            -1.014700     3.979200                    0.0
# 5                            -0.218000    -0.484480                    0.0
# 6                            -1.861500    -0.092136                    0.0
# 7                             0.058389    -3.804400                    0.0
# 8                                  NaN          NaN                    NaN
# 9                             0.149210     0.149210                    0.0
# 10                                 NaN          NaN                    NaN
# 11                                 NaN          NaN                    NaN
# 12                           -0.822140    -0.822150                    0.0
# 13                                 NaN          NaN                    NaN
# 14                                 NaN          NaN                    NaN
# 15                                 NaN          NaN                    NaN
# 16                            0.120090     0.120090                    0.0
# 17                                 NaN          NaN                    NaN
# 18                                 NaN          NaN                    NaN
# 19                                 NaN          NaN                    NaN
# 20                                 NaN          NaN                    NaN
# 21                                 NaN          NaN                    NaN
# 22                                 NaN          NaN                    NaN
# 23                           -0.160050    -0.160040                    0.0
#
#     unclassified_Lachnospiraceae  Coprobacillus  Enterococcus    Other
# 0                      -3.033100       0.280350       2.07960 -1.65810
# 1                            NaN            NaN           NaN      NaN
# 2                      -0.264720       1.967400      -0.82412 -0.44685
# 3                       2.907600       6.399700       4.98700  5.10480
# 4                      -1.014700      -6.452700      -2.17780 -1.54420
# 5                      -0.217620      -0.504010      -2.52060 -1.99110
# 6                      -1.862000      -1.861500       1.02880 -1.57390
# 7                       0.058219       0.058405      -1.04020  0.69655
# 8                            NaN            NaN           NaN      NaN
# 9                       0.149330       0.149210      -0.53718 -0.18033
# 10                           NaN            NaN           NaN      NaN
# 11                           NaN            NaN           NaN      NaN
# 12                     -0.822110      -0.822150      -0.48064 -0.40463
# 13                           NaN            NaN           NaN      NaN
# 14                           NaN            NaN           NaN      NaN
# 15                           NaN            NaN           NaN      NaN
# 16                      0.120130       0.120090       0.12009  0.13895
# 17                           NaN            NaN           NaN      NaN
# 18                           NaN            NaN           NaN      NaN
# 19                           NaN            NaN           NaN      NaN
# 20                           NaN            NaN           NaN      NaN
# 21                           NaN            NaN           NaN      NaN
# 22                           NaN            NaN           NaN      NaN
# 23                     -0.160100      -0.160040      -0.00309 -0.18936

# %%
data['Blautia'].isnull()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23    False
# Name: Blautia, dtype: bool

# %%
data['index'] = data['index'].astype(float)
new_dataset = GPImputer().impute_missing_values(data, ['index'], 'Blautia')
# This is the last version of the imputed data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 data['index'] = data['index'].astype(float)
# ----> 2 new_dataset = GPImputer().impute_missing_values(data, ['index'], 'Blautia')
#
# File ~\Documents\GitHub\MIMIC\mimic\data_imputation\impute_GP.py:171, in GPImputer.impute_missing_values(self, dataset, feature_columns, target_column, kernel)
#     169 results = []
#     170 for kernel in kernels:
# --> 171     m, bic = self.fit(X_train, Y_train, kernel)
#     172     # QUESTION: add mean here? Or always assume the mean is 0?
#     173     results.append([m, bic, kernel])
#
# File ~\Documents\GitHub\MIMIC\mimic\data_imputation\impute_GP.py:98, in GPImputer.fit(self, X_train, Y_train, kernel)
#      95 # optimal_kernel = self._select_kernel(X_train, Y_train)
#      96 m = gpf.models.GPR(
#      97     data=(X_train, Y_train), kernel=kernel(active_dims=[0]))
# ---> 98 res = self.optimize_model_with_scipy(m, X_train, Y_train)
#     100 bic = self.get_BIC(m, res.fun, X_train.shape[0])
#     102 return m, bic
#
# File ~\Documents\GitHub\MIMIC\mimic\data_imputation\impute_GP.py:81, in GPImputer.optimize_model_with_scipy(self, model, X, Y)
#      78 optimizer = gpf.optimizers.Scipy()
#      79 MAXITER = 5000  # FIXME change this to be user-defined
#      80 return optimizer.minimize(
# ---> 81     model.training_loss_closure(X),
#      82     variables=model.trainable_variables,
#      83     method="l-bfgs-b",
#      84     # options={"disp": 50, "maxiter": MAXITER},
#      85     options={"maxiter": MAXITER},
#      86 )
#
# TypeError: InternalDataTrainingLossMixin.training_loss_closure() takes 1 positional argument but 2 were given

# %%
new_dataset2 = GPImputer().impute_missing_values(
    data, ['index'], 'Blautia', kernel='RBF')
# Out:
# Best kernel: <class 'gpflow.kernels.stationaries.SquaredExponential'>
# BIC: -45.666191640980635

# %%
new_dataset3 = GPImputer().impute_missing_values(
    data, ['index'], 'Blautia', kernel='M32')
# Out:
# Best kernel: <class 'gpflow.kernels.stationaries.Matern32'>
# BIC: -45.666191871895016

# %%
new_dataset3 = GPImputer().impute_missing_values(
    data, ['index'], 'Blautia', kernel='M52')
# Out:
# Best kernel: <class 'gpflow.kernels.stationaries.Matern52'>
# BIC: -45.666191854136706
